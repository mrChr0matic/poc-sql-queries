# %%
from time import sleep

while(True):
    print("compute running")
    sleep(420)

# %%
dbutils.secrets.listScopes()

# %%
dbutils.fs.ls("abfss://commoncrawl@databrickspocsigmoid.dfs.core.windows.net/cc-main-2025-05/wet/")

# %%
storage_account = "databrickspocsigmoid"

spark.conf.set(
  f"fs.azure.account.auth.type.{storage_account}.dfs.core.windows.net",
  "SharedKey"
)

# spark.conf.set(
#   f"fs.azure.account.key.{storage_account}.dfs.core.windows.net",
#   dbutils.secrets.get(
#       scope="poc-secrets",
#       key="databrickspocsigmoid-key"
#   )
# )

# %%
storage_account = "databrickspocsigmoid"

spark.conf.set(
    f"fs.azure.account.key.{storage_account}.dfs.core.windows.net",
    dbutils.secrets.get(
        scope="poc-secrets",
        key="databrickspocsigmoid-key"
    )
)

# %%
base_path = "abfss://commoncrawl@databrickspocsigmoid.dfs.core.windows.net/cc-main-2025-05/wet/"
df_files = spark.read.format("binaryFile").load(base_path)
df_files.count()

# %%
df_files.selectExpr(
    "sum(length) / (1024*1024*1024) as total_gb"
).show()

# %%
print("hello")

# %%
base_path = "abfss://commoncrawl@databrickspocsigmoid.dfs.core.windows.net/cc-main-2025-05/wet/"

df_small = (
    spark.read
    .format("binaryFile")
    .load(base_path)
    .limit(20)
)
